# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("deal_data.csv")

# %% [markdown]
# # Display the FIRST 5 Observations

# %%
df.head()
# Out:
#    Unnamed: 0                       SourceFundingID      Source Domain  \
# 0           0  00058d99-4eb8-47d4-9189-01f90ebd86e9  Crunchbase    NaN
# 1           1  00067368-f52d-4ccf-824d-c73115615c4d  Crunchbase    NaN
# 2           2  00172f9e-6c79-4d86-a176-d69fda4e4d77  Crunchbase    NaN
# 3           3  0027cfba-6051-4472-b82e-21ca5687395a  Crunchbase    NaN
# 4           4  0029dad2-c341-4ea7-99e3-2db296f474eb  Crunchbase    NaN
#
#                         SourceCompanyID  PostMoneyValuation     Type  \
# 0  b6204211-01eb-4e84-ba95-4f9780724d30           2450000.0     seed
# 1  ada0db7e-2854-4d21-8e6a-eee86e978182                 NaN     seed
# 2  b8210cf6-6b5f-4697-961c-8ac3e6d419ba                 NaN  venture
# 3  9b400938-bd82-430a-90b6-35663785a5b8                 NaN     seed
# 4  22007017-3d3b-41c1-9b6a-0fd71075614a          10000000.0     seed
#
#   SourceType    Amount              Original_Date  ... Agency Consultancy  \
# 0       seed  320000.0  2020-06-01 00:00:00+00:00  ...                NaN
# 1   pre seed       NaN  2021-01-19 00:00:00+00:00  ...                NaN
# 2    venture       NaN  2011-01-01 00:00:00+00:00  ...                NaN
# 3      angel       NaN  2018-07-31 00:00:00+00:00  ...                NaN
# 4   pre seed       NaN  2020-10-12 00:00:00+00:00  ...                NaN
#
#    Ecosystem GoogleCountry GoogleCity Sectors Region FormationDate  \
# 0        NaN           NaN        NaN     NaN    NaN           NaN
# 1        NaN           NaN        NaN     NaN    NaN           NaN
# 2        NaN           NaN        NaN     NaN    NaN           NaN
# 3        NaN           NaN        NaN     NaN    NaN           NaN
# 4        NaN           NaN        NaN     NaN    NaN           NaN
#
#   Amount_ExchangeRate Amount_USD PostMoneyValuationUSD
# 0                 1.0   320000.0             2450000.0
# 1                 NaN        NaN                   NaN
# 2                 NaN        NaN                   NaN
# 3                 NaN        NaN                   NaN
# 4                 NaN        NaN            10000000.0
#
# [5 rows x 30 columns]

# %% [markdown]
# # Display the last 5 Observations

# %%
df.tail()
# Out:
#       Unnamed: 0 SourceFundingID    Source          Domain SourceCompanyID  \
# 9995        9995          333026  Dealroom  freshworks.com          978385
# 9996        9996          333028  Dealroom    kitepower.nl          953155
# 9997        9997          333512  Dealroom    gentibio.com         1879963
# 9998        9998          333807  Dealroom        terra.do         1880931
# 9999        9999          334097  Dealroom   cancer-iq.com          138437
#
#       PostMoneyValuation     Type SourceType      Amount  \
# 9995        3.500000e+09  venture   series h  85000000.0
# 9996                 NaN  venture   series a         NaN
# 9997                 NaN     seed       seed  20000000.0
# 9998                 NaN     seed       seed   1400000.0
# 9999                 NaN  venture   series a   4800000.0
#
#                   Original_Date  ... Agency Consultancy        Ecosystem  \
# 9995  2020-01-01 00:00:00+00:00  ...              False   Silicon Valley
# 9996  2020-07-01 00:00:00+00:00  ...              False  Amsterdam-Delta
# 9997  2020-08-01 00:00:00+00:00  ...              False           Boston
# 9998  2020-08-01 00:00:00+00:00  ...              False   Silicon Valley
# 9999  2020-08-01 00:00:00+00:00  ...              False          Chicago
#
#       GoogleCountry     GoogleCity                 Sectors            Region  \
# 9995  United States  San Francisco  EdTech;FinTech;AI & BD  Northern America
# 9996    Netherlands          Delft                 AI & BD            Europe
# 9997  United States         Boston           Life Sciences  Northern America
# 9998  United States       Stanford                  EdTech  Northern America
# 9999  United States        Chicago                     NaN  Northern America
#
#                   FormationDate Amount_ExchangeRate  Amount_USD  \
# 9995  2010-01-01 00:00:00+00:00                 1.0  85000000.0
# 9996  2015-01-01 00:00:00+00:00                 NaN         NaN
# 9997  2020-01-01 00:00:00+00:00                 1.0  20000000.0
# 9998  2020-01-01 00:00:00+00:00                 1.0   1400000.0
# 9999  2013-01-01 00:00:00+00:00                 1.0   4800000.0
#
#      PostMoneyValuationUSD
# 9995          3.500000e+09
# 9996                   NaN
# 9997                   NaN
# 9998                   NaN
# 9999                   NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# # Display the Number of rows & Number of columns

# %%
df.shape
# Out:
# (10000, 30)

# %%
df.shape[0]
# Out:
# 10000

# %%
df.shape[1]
# Out:
# 30

# %% [markdown]
# # Display the columns Names and their Data Types

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# SourceFundingID           object
# Source                    object
# Domain                    object
# SourceCompanyID           object
# PostMoneyValuation       float64
# Type                      object
# SourceType                object
# Amount                   float64
# Original_Date             object
# Date                      object
# MonthUnknown             float64
# CreatedAt                 object
# UpdatedAt                 object
# VentureStage              object
# Type_combined             object
# CurrencyCode              object
# ValuationCurrencyCode     object
# ID                        object
# Tech                      object
# Agency Consultancy        object
# Ecosystem                 object
# GoogleCountry             object
# GoogleCity                object
# Sectors                   object
# Region                    object
# FormationDate             object
# Amount_ExchangeRate      float64
# Amount_USD               float64
# PostMoneyValuationUSD    float64
# dtype: object

# %% [markdown]
# # Count the Number of Non-Missing Values for each columns

# %%
df.count
# Out:
# <bound method DataFrame.count of       Unnamed: 0                       SourceFundingID      Source  \
# 0              0  00058d99-4eb8-47d4-9189-01f90ebd86e9  Crunchbase
# 1              1  00067368-f52d-4ccf-824d-c73115615c4d  Crunchbase
# 2              2  00172f9e-6c79-4d86-a176-d69fda4e4d77  Crunchbase
# 3              3  0027cfba-6051-4472-b82e-21ca5687395a  Crunchbase
# 4              4  0029dad2-c341-4ea7-99e3-2db296f474eb  Crunchbase
# ...          ...                                   ...         ...
# 9995        9995                                333026    Dealroom
# 9996        9996                                333028    Dealroom
# 9997        9997                                333512    Dealroom
# 9998        9998                                333807    Dealroom
# 9999        9999                                334097    Dealroom
#
#               Domain                       SourceCompanyID  \
# 0                NaN  b6204211-01eb-4e84-ba95-4f9780724d30
# 1                NaN  ada0db7e-2854-4d21-8e6a-eee86e978182
# 2                NaN  b8210cf6-6b5f-4697-961c-8ac3e6d419ba
# 3                NaN  9b400938-bd82-430a-90b6-35663785a5b8
# 4                NaN  22007017-3d3b-41c1-9b6a-0fd71075614a
# ...              ...                                   ...
# 9995  freshworks.com                                978385
# 9996    kitepower.nl                                953155
# 9997    gentibio.com                               1879963
# 9998        terra.do                               1880931
# 9999   cancer-iq.com                                138437
#
#       PostMoneyValuation     Type SourceType      Amount  \
# 0           2.450000e+06     seed       seed    320000.0
# 1                    NaN     seed   pre seed         NaN
# 2                    NaN  venture    venture         NaN
# 3                    NaN     seed      angel         NaN
# 4           1.000000e+07     seed   pre seed         NaN
# ...                  ...      ...        ...         ...
# 9995        3.500000e+09  venture   series h  85000000.0
# 9996                 NaN  venture   series a         NaN
# 9997                 NaN     seed       seed  20000000.0
# 9998                 NaN     seed       seed   1400000.0
# 9999                 NaN  venture   series a   4800000.0
#
#                   Original_Date  ... Agency Consultancy        Ecosystem  \
# 0     2020-06-01 00:00:00+00:00  ...                NaN              NaN
# 1     2021-01-19 00:00:00+00:00  ...                NaN              NaN
# 2     2011-01-01 00:00:00+00:00  ...                NaN              NaN
# 3     2018-07-31 00:00:00+00:00  ...                NaN              NaN
# 4     2020-10-12 00:00:00+00:00  ...                NaN              NaN
# ...                         ...  ...                ...              ...
# 9995  2020-01-01 00:00:00+00:00  ...              False   Silicon Valley
# 9996  2020-07-01 00:00:00+00:00  ...              False  Amsterdam-Delta
# 9997  2020-08-01 00:00:00+00:00  ...              False           Boston
# 9998  2020-08-01 00:00:00+00:00  ...              False   Silicon Valley
# 9999  2020-08-01 00:00:00+00:00  ...              False          Chicago
#
#       GoogleCountry     GoogleCity                 Sectors            Region  \
# 0               NaN            NaN                     NaN               NaN
# 1               NaN            NaN                     NaN               NaN
# 2               NaN            NaN                     NaN               NaN
# 3               NaN            NaN                     NaN               NaN
# 4               NaN            NaN                     NaN               NaN
# ...             ...            ...                     ...               ...
# 9995  United States  San Francisco  EdTech;FinTech;AI & BD  Northern America
# 9996    Netherlands          Delft                 AI & BD            Europe
# 9997  United States         Boston           Life Sciences  Northern America
# 9998  United States       Stanford                  EdTech  Northern America
# 9999  United States        Chicago                     NaN  Northern America
#
#                   FormationDate Amount_ExchangeRate  Amount_USD  \
# 0                           NaN                 1.0    320000.0
# 1                           NaN                 NaN         NaN
# 2                           NaN                 NaN         NaN
# 3                           NaN                 NaN         NaN
# 4                           NaN                 NaN         NaN
# ...                         ...                 ...         ...
# 9995  2010-01-01 00:00:00+00:00                 1.0  85000000.0
# 9996  2015-01-01 00:00:00+00:00                 NaN         NaN
# 9997  2020-01-01 00:00:00+00:00                 1.0  20000000.0
# 9998  2020-01-01 00:00:00+00:00                 1.0   1400000.0
# 9999  2013-01-01 00:00:00+00:00                 1.0   4800000.0
#
#      PostMoneyValuationUSD
# 0             2.450000e+06
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4             1.000000e+07
# ...                    ...
# 9995          3.500000e+09
# 9996                   NaN
# 9997                   NaN
# 9998                   NaN
# 9999                   NaN
#
# [10000 rows x 30 columns]>

# %% [markdown]
# # summary of all the numerical variables present in our data frame.

# %%
df.describe()
# Out:
#         Unnamed: 0  PostMoneyValuation        Amount  MonthUnknown  \
# count  10000.00000        6.730000e+02  6.863000e+03   9985.000000
# mean    4999.50000        3.130658e+08  3.334735e+07      0.093540
# std     2886.89568        2.979400e+09  5.242597e+08      0.291203
# min        0.00000        4.000000e+00  1.000000e+00      0.000000
# 25%     2499.75000        1.500000e+06  2.595000e+05      0.000000
# 50%     4999.50000        5.000000e+06  1.585000e+06      0.000000
# 75%     7499.25000        2.019000e+07  7.000000e+06      0.000000
# max     9999.00000        6.560000e+10  2.800000e+10      1.000000
#
#        Amount_ExchangeRate    Amount_USD  PostMoneyValuationUSD
# count          6860.000000  6.860000e+03           6.720000e+02
# mean             10.343239  8.312975e+06           1.185788e+08
# std             190.042425  3.488032e+07           4.892961e+08
# min               0.506334  9.394364e-01           3.757746e+00
# 25%               1.000000  2.500000e+05           1.404349e+06
# 50%               1.000000  1.414187e+06           4.371000e+06
# 75%               1.000000  5.500000e+06           1.612500e+07
# max           14254.510000  2.000000e+09           5.500000e+09

# %%
df.describe(include = 'all')
# Out:
#          Unnamed: 0                          SourceFundingID      Source  \
# count   10000.00000                                    10000       10000
# unique          NaN                                     9999          17
# top             NaN  42779360101063788310013250600839766333L  Crunchbase
# freq            NaN                                        2        6473
# mean     4999.50000                                      NaN         NaN
# std      2886.89568                                      NaN         NaN
# min         0.00000                                      NaN         NaN
# 25%      2499.75000                                      NaN         NaN
# 50%      4999.50000                                      NaN         NaN
# 75%      7499.25000                                      NaN         NaN
# max      9999.00000                                      NaN         NaN
#
#                 Domain                       SourceCompanyID  \
# count             6109                                  9979
# unique            2440                                  7176
# top     ambiqmicro.com  b7ac3291-75e4-5029-9800-48372d721af3
# freq                27                                    13
# mean               NaN                                   NaN
# std                NaN                                   NaN
# min                NaN                                   NaN
# 25%                NaN                                   NaN
# 50%                NaN                                   NaN
# 75%                NaN                                   NaN
# max                NaN                                   NaN
#
#         PostMoneyValuation   Type SourceType        Amount  \
# count         6.730000e+02  10000      10000  6.863000e+03
# unique                 NaN      2         37           NaN
# top                    NaN   seed       seed           NaN
# freq                   NaN   6183       3801           NaN
# mean          3.130658e+08    NaN        NaN  3.334735e+07
# std           2.979400e+09    NaN        NaN  5.242597e+08
# min           4.000000e+00    NaN        NaN  1.000000e+00
# 25%           1.500000e+06    NaN        NaN  2.595000e+05
# 50%           5.000000e+06    NaN        NaN  1.585000e+06
# 75%           2.019000e+07    NaN        NaN  7.000000e+06
# max           6.560000e+10    NaN        NaN  2.800000e+10
#
#                     Original_Date  ... Agency Consultancy       Ecosystem  \
# count                        9985  ...               6057            6069
# unique                       2432  ...                  2             359
# top     2019-01-01 00:00:00+00:00  ...              False  Silicon Valley
# freq                          141  ...               5861             845
# mean                          NaN  ...                NaN             NaN
# std                           NaN  ...                NaN             NaN
# min                           NaN  ...                NaN             NaN
# 25%                           NaN  ...                NaN             NaN
# 50%                           NaN  ...                NaN             NaN
# 75%                           NaN  ...                NaN             NaN
# max                           NaN  ...                NaN             NaN
#
#         GoogleCountry     GoogleCity Sectors            Region  \
# count            6067           5694    4493              6065
# unique             71            717     143                 6
# top     United States  San Francisco  EdTech  Northern America
# freq             2875            420    1298              3072
# mean              NaN            NaN     NaN               NaN
# std               NaN            NaN     NaN               NaN
# min               NaN            NaN     NaN               NaN
# 25%               NaN            NaN     NaN               NaN
# 50%               NaN            NaN     NaN               NaN
# 75%               NaN            NaN     NaN               NaN
# max               NaN            NaN     NaN               NaN
#
#                     FormationDate Amount_ExchangeRate    Amount_USD  \
# count                        6034         6860.000000  6.860000e+03
# unique                        507                 NaN           NaN
# top     2014-01-01 00:00:00+00:00                 NaN           NaN
# freq                          483                 NaN           NaN
# mean                          NaN           10.343239  8.312975e+06
# std                           NaN          190.042425  3.488032e+07
# min                           NaN            0.506334  9.394364e-01
# 25%                           NaN            1.000000  2.500000e+05
# 50%                           NaN            1.000000  1.414187e+06
# 75%                           NaN            1.000000  5.500000e+06
# max                           NaN        14254.510000  2.000000e+09
#
#        PostMoneyValuationUSD
# count           6.720000e+02
# unique                   NaN
# top                      NaN
# freq                     NaN
# mean            1.185788e+08
# std             4.892961e+08
# min             3.757746e+00
# 25%             1.404349e+06
# 50%             4.371000e+06
# 75%             1.612500e+07
# max             5.500000e+09
#
# [11 rows x 30 columns]

# %% [markdown]
# # Display the Complete information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             10000 non-null  int64
#  1   SourceFundingID        10000 non-null  object
#  2   Source                 10000 non-null  object
#  3   Domain                 6109 non-null   object
#  4   SourceCompanyID        9979 non-null   object
#  5   PostMoneyValuation     673 non-null    float64
#  6   Type                   10000 non-null  object
#  7   SourceType             10000 non-null  object
#  8   Amount                 6863 non-null   float64
#  9   Original_Date          9985 non-null   object
#  10  Date                   9985 non-null   object
#  11  MonthUnknown           9985 non-null   float64
#  12  CreatedAt              6473 non-null   object
#  13  UpdatedAt              6473 non-null   object
#  14  VentureStage           2231 non-null   object
#  15  Type_combined          10000 non-null  object
#  16  CurrencyCode           9815 non-null   object
#  17  ValuationCurrencyCode  9818 non-null   object
#  18  ID                     10000 non-null  object
#  19  Tech                   5464 non-null   object
#  20  Agency Consultancy     6057 non-null   object
#  21  Ecosystem              6069 non-null   object
#  22  GoogleCountry          6067 non-null   object
#  23  GoogleCity             5694 non-null   object
#  24  Sectors                4493 non-null   object
#  25  Region                 6065 non-null   object
#  26  FormationDate          6034 non-null   object
#  27  Amount_ExchangeRate    6860 non-null   float64
#  28  Amount_USD             6860 non-null   float64
#  29  PostMoneyValuationUSD  672 non-null    float64
# dtypes: float64(6), int64(1), object(23)
# memory usage: 2.3+ MB

# %% [markdown]
# # Handling Duplicates

# %% [markdown]
# This involves 2 steps: Detecting duplicates and Removing duplicates.
#
# To check for the duplicates in our data

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %% [markdown]
# All the function which is used in this file.
#
# To remove the duplicates(if any) we can use the code :

# %%
def clean_funding_round(domain_data):
    global df
    a=["series a", "venture a"]
    df = df[~df['SourceType'].isin(a)]
    return df.head()

def sort_domain_groupby(domain_data):
    domain_data = domain_data.sort_values(by= 'Original_Date', ascending=False)
    return domain_data.head()

def dedude(data):
    df=data.drop_duplicates()
    return df

# %%
clean_funding_round(df)
# Out:
#    Unnamed: 0                       SourceFundingID      Source Domain  \
# 0           0  00058d99-4eb8-47d4-9189-01f90ebd86e9  Crunchbase    NaN
# 1           1  00067368-f52d-4ccf-824d-c73115615c4d  Crunchbase    NaN
# 2           2  00172f9e-6c79-4d86-a176-d69fda4e4d77  Crunchbase    NaN
# 3           3  0027cfba-6051-4472-b82e-21ca5687395a  Crunchbase    NaN
# 4           4  0029dad2-c341-4ea7-99e3-2db296f474eb  Crunchbase    NaN
#
#                         SourceCompanyID  PostMoneyValuation     Type  \
# 0  b6204211-01eb-4e84-ba95-4f9780724d30           2450000.0     seed
# 1  ada0db7e-2854-4d21-8e6a-eee86e978182                 NaN     seed
# 2  b8210cf6-6b5f-4697-961c-8ac3e6d419ba                 NaN  venture
# 3  9b400938-bd82-430a-90b6-35663785a5b8                 NaN     seed
# 4  22007017-3d3b-41c1-9b6a-0fd71075614a          10000000.0     seed
#
#   SourceType    Amount              Original_Date  ... Agency Consultancy  \
# 0       seed  320000.0  2020-06-01 00:00:00+00:00  ...                NaN
# 1   pre seed       NaN  2021-01-19 00:00:00+00:00  ...                NaN
# 2    venture       NaN  2011-01-01 00:00:00+00:00  ...                NaN
# 3      angel       NaN  2018-07-31 00:00:00+00:00  ...                NaN
# 4   pre seed       NaN  2020-10-12 00:00:00+00:00  ...                NaN
#
#    Ecosystem GoogleCountry GoogleCity Sectors Region FormationDate  \
# 0        NaN           NaN        NaN     NaN    NaN           NaN
# 1        NaN           NaN        NaN     NaN    NaN           NaN
# 2        NaN           NaN        NaN     NaN    NaN           NaN
# 3        NaN           NaN        NaN     NaN    NaN           NaN
# 4        NaN           NaN        NaN     NaN    NaN           NaN
#
#   Amount_ExchangeRate Amount_USD PostMoneyValuationUSD
# 0                 1.0   320000.0             2450000.0
# 1                 NaN        NaN                   NaN
# 2                 NaN        NaN                   NaN
# 3                 NaN        NaN                   NaN
# 4                 NaN        NaN            10000000.0
#
# [5 rows x 30 columns]

# %%
sort_domain_groupby(df)
# Out:
#       Unnamed: 0                       SourceFundingID      Source Domain  \
# 5041        5041  8129def9-8a71-4413-9d74-996418274749  Crunchbase    NaN
# 7531        7531  e5090a2b-672b-4a04-a2a3-05d7897dee92  Crunchbase    NaN
# 3983        3983  57527dd5-d800-4dfc-968c-d92d3071d752  Crunchbase    NaN
# 3476        3476  47268e6b-ad2b-4d93-b704-db843ab3fcb4  Crunchbase    NaN
# 7106        7106  d3ba50cc-3db2-47eb-832a-ce2622e202a9  Crunchbase    NaN
#
#                            SourceCompanyID  PostMoneyValuation  Type  \
# 5041  df34ad1b-f6cc-4e3a-8f10-9c61c7e6b785           5200000.0  seed
# 7531  401d053e-65ef-4842-8d9e-b40089cb7548           2000000.0  seed
# 3983  fcd7b7af-5939-4943-9fcf-329f390e8dc9                 NaN  seed
# 3476  bc3dd961-bcb1-4ece-97aa-8f42f236a3f3                 NaN  seed
# 7106  3b1c45ed-e8aa-47b7-950b-7a6b78557837          10000000.0  seed
#
#      SourceType    Amount              Original_Date  ... Agency Consultancy  \
# 5041   pre seed  200000.0  2021-03-22 00:00:00+00:00  ...                NaN
# 7531   pre seed       NaN  2021-03-01 00:00:00+00:00  ...                NaN
# 3983   pre seed       NaN  2021-03-01 00:00:00+00:00  ...                NaN
# 3476   pre seed       NaN  2021-03-01 00:00:00+00:00  ...                NaN
# 7106       seed       NaN  2021-03-01 00:00:00+00:00  ...                NaN
#
#       Ecosystem GoogleCountry GoogleCity Sectors Region FormationDate  \
# 5041        NaN           NaN        NaN     NaN    NaN           NaN
# 7531        NaN           NaN        NaN     NaN    NaN           NaN
# 3983        NaN           NaN        NaN     NaN    NaN           NaN
# 3476        NaN           NaN        NaN     NaN    NaN           NaN
# 7106        NaN           NaN        NaN     NaN    NaN           NaN
#
#      Amount_ExchangeRate Amount_USD PostMoneyValuationUSD
# 5041                 1.0   200000.0             5200000.0
# 7531                 NaN        NaN             2000000.0
# 3983                 NaN        NaN                   NaN
# 3476                 NaN        NaN                   NaN
# 7106                 NaN        NaN            10000000.0
#
# [5 rows x 30 columns]

# %%
dedude(df)
# Out:
#       Unnamed: 0                       SourceFundingID      Source  \
# 0              0  00058d99-4eb8-47d4-9189-01f90ebd86e9  Crunchbase
# 1              1  00067368-f52d-4ccf-824d-c73115615c4d  Crunchbase
# 2              2  00172f9e-6c79-4d86-a176-d69fda4e4d77  Crunchbase
# 3              3  0027cfba-6051-4472-b82e-21ca5687395a  Crunchbase
# 4              4  0029dad2-c341-4ea7-99e3-2db296f474eb  Crunchbase
# ...          ...                                   ...         ...
# 9992        9992                                332587    Dealroom
# 9993        9993                                332642    Dealroom
# 9995        9995                                333026    Dealroom
# 9997        9997                                333512    Dealroom
# 9998        9998                                333807    Dealroom
#
#                    Domain     Type SourceType Type_combined  \
# 0          ambiqmicro.com     seed       seed          seed
# 1          ambiqmicro.com     seed   pre seed          seed
# 2          ambiqmicro.com  venture    venture       venture
# 3          ambiqmicro.com     seed      angel          seed
# 4          ambiqmicro.com     seed   pre seed          seed
# ...                   ...      ...        ...           ...
# 9992           navvis.com     seed       seed          seed
# 9993  realviewimaging.com  venture   series c     venture c
# 9995       freshworks.com  venture   series h     venture h
# 9997         gentibio.com     seed       seed          seed
# 9998             terra.do     seed       seed          seed
#
#                                             ID
# 0     152199716243541657317250720094442187905L
# 1     142536850701974396225840320902421968467L
# 2      37894384329600705588367870869526617264L
# 3      26919707984490913180431418999218181315L
# 4     176394159817646162691393134644216231257L
# ...                                        ...
# 9992  285331051029034806354002227097975347595L
# 9993   23868052470596192702290425666333676381L
# 9995  227304718277758843025774292206376079272L
# 9997  294490176098569250183752387662097686058L
# 9998  146941211178945977224103976952404458367L
#
# [8716 rows x 8 columns]

# %% [markdown]
# # Handling Missing Values

# %% [markdown]
# This involves 2 steps:
#
#             Detecting the missing values and Treatment of the Missing Values
#
# Detecting the Missing Values

# %%
df.isna()
# Out:
#       Unnamed: 0  SourceFundingID  Source  Domain  SourceCompanyID  \
# 0          False            False   False    True            False
# 1          False            False   False    True            False
# 2          False            False   False    True            False
# 3          False            False   False    True            False
# 4          False            False   False    True            False
# ...          ...              ...     ...     ...              ...
# 9992       False            False   False   False            False
# 9993       False            False   False   False            False
# 9995       False            False   False   False            False
# 9997       False            False   False   False            False
# 9998       False            False   False   False            False
#
#       PostMoneyValuation   Type  SourceType  Amount  Original_Date  ...  \
# 0                  False  False       False   False          False  ...
# 1                   True  False       False    True          False  ...
# 2                   True  False       False    True          False  ...
# 3                   True  False       False    True          False  ...
# 4                  False  False       False    True          False  ...
# ...                  ...    ...         ...     ...            ...  ...
# 9992                True  False       False    True          False  ...
# 9993                True  False       False   False          False  ...
# 9995               False  False       False   False          False  ...
# 9997                True  False       False   False          False  ...
# 9998                True  False       False   False          False  ...
#
#       Agency Consultancy  Ecosystem  GoogleCountry  GoogleCity  Sectors  \
# 0                   True       True           True        True     True
# 1                   True       True           True        True     True
# 2                   True       True           True        True     True
# 3                   True       True           True        True     True
# 4                   True       True           True        True     True
# ...                  ...        ...            ...         ...      ...
# 9992               False      False          False       False    False
# 9993               False      False          False       False    False
# 9995               False      False          False       False    False
# 9997               False      False          False       False    False
# 9998               False      False          False       False    False
#
#       Region  FormationDate  Amount_ExchangeRate  Amount_USD  \
# 0       True           True                False       False
# 1       True           True                 True        True
# 2       True           True                 True        True
# 3       True           True                 True        True
# 4       True           True                 True        True
# ...      ...            ...                  ...         ...
# 9992   False          False                 True        True
# 9993   False          False                False       False
# 9995   False          False                False       False
# 9997   False          False                False       False
# 9998   False          False                False       False
#
#       PostMoneyValuationUSD
# 0                     False
# 1                      True
# 2                      True
# 3                      True
# 4                     False
# ...                     ...
# 9992                   True
# 9993                   True
# 9995                  False
# 9997                   True
# 9998                   True
#
# [8716 rows x 30 columns]

# %% [markdown]
# percentage of missing values in each columns.

# %%
df.isna().sum()/df.shape[0]
# Out:
# Unnamed: 0               0.000000
# SourceFundingID          0.000000
# Source                   0.000000
# Domain                   0.416475
# SourceCompanyID          0.002180
# PostMoneyValuation       0.933341
# Type                     0.000000
# SourceType               0.000000
# Amount                   0.330083
# Original_Date            0.001262
# Date                     0.001262
# MonthUnknown             0.001262
# CreatedAt                0.329853
# UpdatedAt                0.329853
# VentureStage             0.891349
# Type_combined            0.000000
# CurrencyCode             0.020193
# ValuationCurrencyCode    0.019849
# ID                       0.000000
# Tech                     0.477283
# Agency Consultancy       0.422097
# Ecosystem                0.420721
# GoogleCountry            0.420721
# GoogleCity               0.456631
# Sectors                  0.575493
# Region                   0.420950
# FormationDate            0.424736
# Amount_ExchangeRate      0.330427
# Amount_USD               0.330427
# PostMoneyValuationUSD    0.933456
# dtype: float64

# %% [markdown]
# # Missing Value Treatment

# %% [markdown]
# To treat the missing values we can opt for a method from the following :
#
# 1) Drop the variable
#
# 2) Drop the observation(s)
#
# 3) Missing Value Imputation

# %% [markdown]
# Since it is a categorical variable, let’s impute the values by mode

# %%
df.Domain.mode()[0]
# Out:
# 'ambiqmicro.com'

# %%
df.Domain.fillna(df.Domain.mode()[0],inplace=True)
# Out:
# /opt/python3.6.7/lib/python3.6/site-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
df.isna().sum()/df.shape[0]
# Out:
# Unnamed: 0               0.000000
# SourceFundingID          0.000000
# Source                   0.000000
# Domain                   0.000000
# SourceCompanyID          0.002180
# PostMoneyValuation       0.933341
# Type                     0.000000
# SourceType               0.000000
# Amount                   0.330083
# Original_Date            0.001262
# Date                     0.001262
# MonthUnknown             0.001262
# CreatedAt                0.329853
# UpdatedAt                0.329853
# VentureStage             0.891349
# Type_combined            0.000000
# CurrencyCode             0.020193
# ValuationCurrencyCode    0.019849
# ID                       0.000000
# Tech                     0.477283
# Agency Consultancy       0.422097
# Ecosystem                0.420721
# GoogleCountry            0.420721
# GoogleCity               0.456631
# Sectors                  0.575493
# Region                   0.420950
# FormationDate            0.424736
# Amount_ExchangeRate      0.330427
# Amount_USD               0.330427
# PostMoneyValuationUSD    0.933456
# dtype: float64

# %%
df.dropna(axis=1,inplace=True)
# Out:
# /opt/python3.6.7/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# SourceFundingID    object
# Source             object
# Domain             object
# Type               object
# SourceType         object
# Type_combined      object
# ID                 object
# dtype: object

# %%
df
# Out:
#       Unnamed: 0                       SourceFundingID      Source  \
# 0              0  00058d99-4eb8-47d4-9189-01f90ebd86e9  Crunchbase
# 1              1  00067368-f52d-4ccf-824d-c73115615c4d  Crunchbase
# 2              2  00172f9e-6c79-4d86-a176-d69fda4e4d77  Crunchbase
# 3              3  0027cfba-6051-4472-b82e-21ca5687395a  Crunchbase
# 4              4  0029dad2-c341-4ea7-99e3-2db296f474eb  Crunchbase
# ...          ...                                   ...         ...
# 9992        9992                                332587    Dealroom
# 9993        9993                                332642    Dealroom
# 9995        9995                                333026    Dealroom
# 9997        9997                                333512    Dealroom
# 9998        9998                                333807    Dealroom
#
#                    Domain     Type SourceType Type_combined  \
# 0          ambiqmicro.com     seed       seed          seed
# 1          ambiqmicro.com     seed   pre seed          seed
# 2          ambiqmicro.com  venture    venture       venture
# 3          ambiqmicro.com     seed      angel          seed
# 4          ambiqmicro.com     seed   pre seed          seed
# ...                   ...      ...        ...           ...
# 9992           navvis.com     seed       seed          seed
# 9993  realviewimaging.com  venture   series c     venture c
# 9995       freshworks.com  venture   series h     venture h
# 9997         gentibio.com     seed       seed          seed
# 9998             terra.do     seed       seed          seed
#
#                                             ID
# 0     152199716243541657317250720094442187905L
# 1     142536850701974396225840320902421968467L
# 2      37894384329600705588367870869526617264L
# 3      26919707984490913180431418999218181315L
# 4     176394159817646162691393134644216231257L
# ...                                        ...
# 9992  285331051029034806354002227097975347595L
# 9993   23868052470596192702290425666333676381L
# 9995  227304718277758843025774292206376079272L
# 9997  294490176098569250183752387662097686058L
# 9998  146941211178945977224103976952404458367L
#
# [8716 rows x 8 columns]

# %% [markdown]
# # Analysis using Charts

# %% [markdown]
# #                                                     Univariate Analysis

# %% [markdown]
# To see the distribution of data we create Box plots and Histograms.

# %% [markdown]
#                                     Distribution of Type

# %% [markdown]
# Histogram

# %%
df.Type.hist()
plt.show()

# %% [markdown]
# We have another way to create this chart by directly using matplotlib!

# %%
plt.hist(df.Type)
plt.grid(True)
plt.show()

# %% [markdown]
# # For Categorical Variables :

# %% [markdown]
# To see the distribution of data we create frequency plots like Bar charts, Horizontal Bar charts, etc.
#
# To see the composition of data we create Pie charts.

# %% [markdown]
#                                   Composition of Type

# %%
df.groupby('Type').SourceType.count().plot(kind='pie')
plt.show()

# %% [markdown]
# Distribution of SourceType

# %%
sns.countplot(df.SourceType)
plt.show()
# Out:
# /opt/python3.6.7/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Distribution of Source

# %%
sns.countplot(df.Source)
plt.show()
# Out:
# /opt/python3.6.7/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# we take two variables at a time and create charts on them. Since we have 2 types of variables Categorical and Numerical so there can be 3 cases in bivariate analysis :

# %% [markdown]
# Numerical & Numerical:
#
# To see the relationship between the 2 variables we create Scatter Plots and a Correlation Matrix with a Heatmap on the top.

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# Considering 2 categorical variables Type and SourceType

# %%
df.plot(x='Type', y='SourceType', kind='scatter')
plt.show()

# %% [markdown]
# we can use another syntax for scatter graph.

# %% [markdown]
# # Correlation Matrix

# %% [markdown]
# Finding a correlation between all the numeric columns

# %%
df.select_dtypes(['float64' , 'int64']).corr()
# Out:
#             Unnamed: 0
# Unnamed: 0         1.0

# %% [markdown]
# # Heatmap

# %% [markdown]
# Creating a heatmap using Seaborn on the top of the correlation matrix obtained above to visualize the correlation between the different numerical columns of the data. This is done when we have a large number of variables.

# %%
sns.heatmap(df.select_dtypes(['float64' , 'int64']).corr(),annot=True)
plt.show()
